# %% [markdown]
# <div style="border:1px solid black; padding:10px; background-color: #F8F8F8;">
#     <strong> <b>Notions et fonctions</b></strong><br>.
#     <i>
#     <ul>
#        <li> geopanda *</li>
#         <li> Carte thématique</li>
#         <li>  *</li>
#     </ul>
#     <strong> Comme d'habitude certaines cellules sont dépendantes de cellules précédentes. Il faut donc les éxécuter en suivant leur ordre dans la page</strong>
# </div>
#
#
#
# <b>révisions</b>
# <ul>
#     <li> </li>
#
# </ul>

# %% [markdown]
# # Représentation cartographique de variables qualitatives

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd

# %% [markdown]
# Lorsqu'une variable qualitative a une dimension spatiale la représentation graphique la plus adéquate est la carte.<br>
# Si la dimension spatiale et cartographique est centrale dans un projet de recherhes il est mieux d'utiliser les outils conçus pour cela, c'est à dire les systèmes d'information géographique, et à l'heure où j'écris Qgis, qui permet (plus ou moins) des sorties dans des formats non propriétaires. La maîtrise de logiciels de ce type cependant implique un apprentissage qui est long et qui n'est pas toujours aisé. <br>
# Si vos besoins sont ponctuels il est tout à fait possible de réaliser des représentations cartographiques simples en utilisant Python, et plus particulièrement la bibliothèque Geopandas, souvent dans le cadre d'un environnement qui intègre également les bibliothèques permettant de visualiser et de travailler les données (c'est à dire a minima pandas).

# %% [markdown]
# Nous utilisons pour l'exemple les mêmes donées que pour le carnet précédent soit le tableau décrivant les prisonniers de Bicêtre dont vous trouverez la description dans la page précédente. </br>
# Première étape donc placer les données dans un dataframe et vérifiez qu'elles sont bien identifiées et ouvertes

# %%
chemin_fichier = 'Doc6/data2.xlsx'  
df = pd.read_excel(chemin_fichier)

# Affichage des premières lignes du DataFrame pour vérification
print(df.head())
# Out:
#     id        nom            prenoms   age  taille  profession  \
# 0  360    Barbeth          Philibert  46.0   171.0     Cordier
# 1  268    Legrain      Pierre Alexis  18.0   170.0     Vannier
# 2  683    Ancieux           Benjamin  18.0   168.0     Boucher
# 3  751     Clouet      Paul Frédéric  17.0   155.0  Domestique
# 4  933  Mettivier  François Philippe  28.0   183.0       Maçon
#
#      naissance_lieu naissance_departement  NumDpt domicile_commune  ...  \
# 0          Feillens                   Ain     1.0            Paris  ...
# 1      Borlieux [?]                 Aisne     2.0            Paris  ...
# 2      Capelle (La)                 Aisne     2.0            Paris  ...
# 3  Ferté-Milon (La)                 Aisne     2.0            Paris  ...
# 4            Epieds                 Aisne     2.0          Comegis  ...
#
#                                        etat_physique  \
# 0  Une petite cicatrice sur le pouce de la main g...
# 1  Une forte cicatrice sur le dessus de la main d...
# 2  Une forte cicatrice à la tempe gauche, une for...
# 3  Une cicatrice sur le côté de la pommette du po...
# 4                                                NaN
#
#                          autorite date_entree  \
# 0                Préfet de Police  1815-07-29
# 1  Directeur général de la Police  1814-11-21
# 2                Préfet de Police  1816-09-17
# 3                Préfet de Police  1817-02-12
# 4                Préfet de Police  1822-11-08
#
#                                                motif duree_detention_prevue  \
# 0  Détenu pendant 15 jours pour avoir tenu des je...               15 jours
# 1   Jusqu'à nouvel ordre comme mauvais sujet voleur.                    NaN
# 2     Pendant quinze jours comme tenant jeu prohibé.               15 jours
# 3              Jusqu'à nouvel ordre comme pédéraste.                    NaN
# 4  Jusqu'à nouvel ordre comme réclusionnaire libé...                    NaN
#
#   duree_detention_effective date_sortie               transfert  \
# 0                      13.0  1815-08-11                 Liberté
# 1                       5.0  1814-11-26  Direction de la Police
# 2                      14.0  1816-10-01                 Liberté
# 3                      20.0  1817-03-04    Préfecture de police
# 4                      16.0  1822-11-24    Préfecture de police
#
#                                         observations rang
# 0  Réintégré le 19/6/1816, pour 15 jours, comme t...  360
# 1                                                NaN  268
# 2                                                NaN  683
# 3                                                NaN  751
# 4                                                NaN  933
#
# [5 rows x 23 columns]

# %% [markdown]
# Nous avons vu précedememnt que la repréentation graphique la plus adaptée pour certaines variables, en particulier bien sûr les lieux de naissance et de résidence sont des représentations cartographiques. <br>
# Notons que ce que nous représentons en ce cas ce ne sont pas les variables elles même mais la fréquence de chacune des modalités.

# %% [markdown]
# Trouver un fond de carte de la France par départements n'est de nos jours pas très compliqué encore faut il qu'il soit lisible et manipulable par Geopanda

# %%
# Chemin vers le fichier shapefile des départements
chemin_fichier = "Doc6/departements.geojson"

# Charger les données dans un GeoDataFrame
departements_gdf = gpd.read_file(chemin_fichier)

# Afficher les 5 premières lignes du GeoDataFrame
print(departements_gdf.head())
# Out:
#   code                      nom  \
# 0   01                      Ain
# 1   02                    Aisne
# 2   03                   Allier
# 3   04  Alpes-de-Haute-Provence
# 4   05             Hautes-Alpes
#
#                                             geometry
# 0  POLYGON ((4.78021 46.17668, 4.78024 46.18905, ...
# 1  POLYGON ((3.17296 50.01131, 3.17382 50.01186, ...
# 2  POLYGON ((3.03207 46.79491, 3.03424 46.79080, ...
# 3  POLYGON ((5.67604 44.19143, 5.67817 44.19051, ...
# 4  POLYGON ((6.26057 45.12685, 6.26417 45.12641, ...

# %%
# Convertir la colonne 'NumDpt' en chaîne, en supprimant le '.0' pour les nombres entiers
df['NumDpt'] = df['NumDpt'].apply(lambda x: str(int(x)) if x == x // 1 else str(x))

# %%
df_filtered = df[(df['NumDpt'] != 100) & (df['NumDpt'].notnull())]
# nous écartons les valeurs nulles et les individus nés hors de France

# %%
df_aggregated = df_filtered.groupby('NumDpt').size().reset_index(name='count')
# Nous comptons le nombre d'individus nés dans chaque département

# %%
# Convertir le code du département en str dans les deux DataFrames si nécessaire
departements_gdf['code'] = departements_gdf['code'].astype(str)
df_aggregated['NumDpt'] = df_aggregated['NumDpt'].astype(str)

# Fusionner
merged_gdf = departements_gdf.merge(df_aggregated, left_on='code', right_on='NumDpt', how='left')

# nous créeons un nouveau dataframe qui contient cette donnée et les données fournies par le fond de carte qui sont nécessaires

# %%
import matplotlib.pyplot as plt

# Réglage pour une belle carte
fig, ax = plt.subplots(1, 1, figsize=(10, 10))
merged_gdf.plot(column='count', ax=ax, legend=True,
                legend_kwds={'label': "Nombre d'individus par département",
                             'orientation': "horizontal"})
plt.show()

# %% [markdown]
# Nous avons un évident problème. Plus exactement plusieurs. Le premier est que les départements de la Seine et de la Seine et Oise sont le départemnet de naissance de nombreux prisonniers, du coup une échelle linéaire ne fait apparaître que cette évidente suprématie et l'absence de certains départements en Aquitaine ou dans l'est de la France partiulièrement qui sont peu ou pas représentés. </br>
# C'est un problème classiquement résolu par une transformation des données, passant soit par une discrétisation soit utilisant le Log, qui permet d'avoir sur la même figure des données qui ne sont pas de même ordre de grandeur. <br>
# Ci dessous le produit d'une transformation log.

# %%
fig, ax = plt.subplots(1, 1, figsize=(10, 10))

# Remplacer les valeurs 0 par une petite valeur (pour permettre la transformation logarithmique)
merged_gdf['count_log'] = merged_gdf['count'].replace(0, np.nan)
min_nonzero = merged_gdf['count_log'][merged_gdf['count_log'] > 0].min()
merged_gdf['count_log'] = merged_gdf['count_log'].fillna(min_nonzero)

# Appliquer la transformation logarithmique
merged_gdf['count_log'] = np.log(merged_gdf['count_log'])

# Dessiner la carte avec l'échelle de couleur logarithmique
merged_gdf.plot(column='count_log', ax=ax, legend=True,
                legend_kwds={'label': "Logarithme du nombre d'individus par département",
                             'orientation': "horizontal"})
plt.show()

# %% [markdown]
# Il apparait que, les prisons de Bicètre recrutent alors préférentielllement en Ile de France, mais que cette aire se prolonge, par dela même le bassin parisien vers les campagnes normandes et le nord de la France. La présence de deux départements auvergnants, singularité pour la France du sud de la Loire corrspond à la présence d'une importantte population migrante, employée souvent dans la construction, en provenance d'Auvergne, dont le réprésentant littéraire le plus célèbre est Gavorche, gamin de Paris qui porte une veste auvergnante. </br>
# La question propre à l'historien sera de déterminer si le recrutement de Bicêtre correspond peu ou prou à celui de l'agglomération parisienne, sinon de ses résidents, du moins de la popualtion qui la traverse, ce qui supposera une mise en regard d'autres données. <br>
# Le jeu de données construit par l'historien ne se comprend et ne s'étudie jamais sans référence à d'autres données historiques et à l'historiographie.

# %% [markdown]
# L'autre problème loin d'être trivial pour les historines est celui du fond de carte à utliser. S'il est aisé de trouver des fichiers décrivant les réalités géograpiques contemporaines, il est bien plus difficile de trouver des fonds de carte adaptés à des données historiques. <br>
# La France n'a pas les mêmes contours aujourd'hui que durant le premier XIXe siècle. Les contours de certains département ont changé, en partiuclier celui des départements, la Seine et la Seine et Oise ayant disparu du fait de la réfome de 1964. </br>
# Notre carte, parlante certes et utilisable dans le cadre d'une exploration de données est cependant parfaitement fausse et impropre à la publication.

# %%
# Chemin vers le fichier shapefile des départements
chemin_fichier = "Doc6/dpthist.geojson"

# Charger les données dans un GeoDataFrame
departements2_gdf = gpd.read_file(chemin_fichier)

# Afficher les 5 premières lignes du GeoDataFrame
print(departements2_gdf.head())
# Out:
#          Noms_depts               NOM DNUM DNUM_2               DPT    EFFEC  \
# 0     Pas-de-Calais     Pas-de-Calais  D62    D62     Pas-de-Calais  30399.0
# 1             Somme             Somme  D80    D80             Somme  32139.0
# 2  Seine-Inférieure  Seine-Inférieure  D76    D76  Seine-Inférieure  39696.0
# 3              Oise              Oise  D60    D60              Oise  35469.0
# 4              Eure              Eure  D27    D27              Eure  18614.0
#
#             Dpt_2   _1990  _1891 DNUM_3            depart    SEINE  \
# 0   Pas-de-Calais  1433.2  874.4    D62     Pas-de-Calais  30399.0
# 1           Somme   547.8  546.5    D80             Somme  32139.0
# 2  Seine-Maritime  1223.4  839.9    D76  Seine-Inférieure  39696.0
# 3            Oise   725.6  401.8    D60              Oise  35469.0
# 4            Eure   513.8  349.5    D27              Eure  18614.0
#
#    Français_PARIS  _91_Attraction       idd  SEXE_1   SEXE_2  ens_paris  \
# 0         22362.0       25.574108  DPNAI=62  6907.0   9837.0    16744.0
# 1         25192.0       46.096981  DPNAI=80  4087.0   5745.0     9832.0
# 2         30894.0       36.782950  DPNAI=76  8249.0  11707.0    19956.0
# 3         26150.0       65.082130  DPNAI=60  4788.0   7510.0    12298.0
# 4         14231.0       40.718169  DPNAI=27  3397.0   5469.0     8866.0
#
#    _1990_attrac                                           geometry
# 0     11.682947  POLYGON ((2.08636 51.00950, 2.09276 50.98939, ...
# 1     17.948156  POLYGON ((1.59605 50.36760, 1.58625 50.36846, ...
# 2     16.311918  POLYGON ((1.35645 50.05725, 1.34909 50.05435, ...
# 3     16.948732  POLYGON ((1.72037 49.39929, 1.73093 49.38741, ...
# 4     17.255742  POLYGON ((1.69346 49.22057, 1.67972 49.20487, ...

# %%
# Afficher les noms des colonnes
print("Noms des colonnes:", departements2_gdf.columns)

# Afficher les types de données
print("\nTypes de données:")
print(departements2_gdf.dtypes)

# Décrire les données
print("\nDescription des données:")
print(departements2_gdf.describe(include='all'))

# Afficher les informations du DataFrame
print("\nInformations du DataFrame:")
departements2_gdf.info()
# Out:
# Noms des colonnes: Index(['Noms_depts', 'NOM', 'DNUM', 'DNUM_2', 'DPT', 'EFFEC', 'Dpt_2', '_1990',
#        '_1891', 'DNUM_3', 'depart', 'SEINE', 'Français_PARIS',
#        '_91_Attraction', 'idd', 'SEXE_1', 'SEXE_2', 'ens_paris',
#        '_1990_attrac', 'geometry'],
#       dtype='object')
#
# Types de données:
# Noms_depts          object
# NOM                 object
# DNUM                object
# DNUM_2              object
# DPT                 object
# EFFEC              float64
# Dpt_2               object
# _1990              float64
# _1891              float64
# DNUM_3              object
# depart              object
# SEINE              float64
# Français_PARIS     float64
# _91_Attraction     float64
# idd                 object
# SEXE_1             float64
# SEXE_2             float64
# ens_paris          float64
# _1990_attrac       float64
# geometry          geometry
# dtype: object
#
# Description des données:
#            Noms_depts            NOM DNUM DNUM_2                    DPT  \
# count              88             88   88     88                     88
# unique             88             88   86     86                     86
# top     Pas-de-Calais  Pas-de-Calais  D65    D65  Pyrénées (Hautes-)...
# freq                1              1    3      3                      3
# mean              NaN            NaN  NaN    NaN                    NaN
# std               NaN            NaN  NaN    NaN                    NaN
# min               NaN            NaN  NaN    NaN                    NaN
# 25%               NaN            NaN  NaN    NaN                    NaN
# 50%               NaN            NaN  NaN    NaN                    NaN
# 75%               NaN            NaN  NaN    NaN                    NaN
# max               NaN            NaN  NaN    NaN                    NaN
#
#                EFFEC               Dpt_2        _1990        _1891 DNUM_3  \
# count      88.000000                  88    88.000000    88.000000     88
# unique           NaN                  86          NaN          NaN     86
# top              NaN  Pyrénées (Hautes-)          NaN          NaN    D65
# freq             NaN                   3          NaN          NaN      3
# mean    17669.420455                 NaN   521.656818   400.850000    NaN
# std     14357.284744                 NaN   405.765627   216.812409    NaN
# min      1667.000000                 NaN     0.000000    83.700000    NaN
# 25%      6861.000000                 NaN   264.775000   280.775000    NaN
# 50%     15185.000000                 NaN   391.250000   350.100000    NaN
# 75%     25484.250000                 NaN   603.275000   457.400000    NaN
# max     89886.000000                 NaN  2531.900000  1736.300000    NaN
#
#                        depart         SEINE  Français_PARIS  _91_Attraction  \
# count                      88     88.000000       88.000000       88.000000
# unique                     86           NaN             NaN             NaN
# top     Pyrénées (Hautes-)...           NaN             NaN             NaN
# freq                        3           NaN             NaN             NaN
# mean                      NaN  17669.420455    13847.897727       35.554111
# std                       NaN  14357.284744    10369.392416       24.653015
# min                       NaN   1667.000000     1380.000000        6.368910
# 25%                       NaN   6861.000000     5757.500000       15.507591
# 50%                       NaN  15185.000000    12585.000000       27.942338
# 75%                       NaN  25484.250000    19686.000000       51.661599
# max                       NaN  89886.000000    59994.000000      113.125876
#
#              idd        SEXE_1        SEXE_2     ens_paris  _1990_attrac  \
# count         88     88.000000     88.000000     88.000000     88.000000
# unique        86           NaN           NaN           NaN           NaN
# top     DPNAI=65           NaN           NaN           NaN           NaN
# freq           3           NaN           NaN           NaN           NaN
# mean         NaN   3243.693182   4441.886364   7685.579545     16.024907
# std          NaN   2220.605428   2978.169091   5175.606015      7.198880
# min          NaN      0.000000      0.000000      0.000000      0.000000
# 25%          NaN   1470.750000   2077.250000   3498.000000     10.654782
# 50%          NaN   2889.500000   4039.000000   6864.000000     15.395766
# 75%          NaN   4272.500000   5948.750000  10233.000000     20.403640
# max          NaN  12040.000000  14951.000000  26991.000000     41.877757
#
#                                                  geometry
# count                                                  88
# unique                                                 88
# top     POLYGON ((2.086362097465047 51.00949840131914,...
# freq                                                    1
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
# Informations du DataFrame:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 88 entries, 0 to 87
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Noms_depts      88 non-null     object
#  1   NOM             88 non-null     object
#  2   DNUM            88 non-null     object
#  3   DNUM_2          88 non-null     object
#  4   DPT             88 non-null     object
#  5   EFFEC           88 non-null     float64
#  6   Dpt_2           88 non-null     object
#  7   _1990           88 non-null     float64
#  8   _1891           88 non-null     float64
#  9   DNUM_3          88 non-null     object
#  10  depart          88 non-null     object
#  11  SEINE           88 non-null     float64
#  12  Français_PARIS  88 non-null     float64
#  13  _91_Attraction  88 non-null     float64
#  14  idd             88 non-null     object
#  15  SEXE_1          88 non-null     float64
#  16  SEXE_2          88 non-null     float64
#  17  ens_paris       88 non-null     float64
#  18  _1990_attrac    88 non-null     float64
#  19  geometry        88 non-null     geometry
# dtypes: float64(10), geometry(1), object(9)
# memory usage: 13.9+ KB

# %%
# Représenter les contours des polygones
fig, ax = plt.subplots(1, 1, figsize=(10, 6))
departements2_gdf.plot(ax=ax, edgecolor='black', facecolor='none')  # Contours en noir, pas de remplissage
plt.title('Contours des polygones')
plt.show()

# %%
# Combinaison et affichage des valeurs des colonnes 'Nom' et 'DNUM'
pd.set_option('display.max_rows', None)

print(departements2_gdf['NOM'] + ", DNUM: " + departements2_gdf['DNUM'].astype(str))

pd.reset_option('display.max_rows')
# Out:
# 0           Pas-de-Calais, DNUM: D62
# 1                   Somme, DNUM: D80
# 2        Seine-Inférieure, DNUM: D76
# 3                    Oise, DNUM: D60
# 4                    Eure, DNUM: D27
# 5           Seine-et-Oise, DNUM: D78
# 6                   Aisne, DNUM: D02
# 7          Seine-et-Marne, DNUM: D77
# 8                  Loiret, DNUM: D45
# 9            Eure-et-Loir, DNUM: D28
# 10               Calvados, DNUM: D14
# 11                   Orne, DNUM: D61
# 12                 Manche, DNUM: D50
# 13              Finistère, DNUM: D29
# 14               Morbihan, DNUM: D56
# 15          Côtes-du-Nord, DNUM: D22
# 16        Ille-et-Vilaine, DNUM: D35
# 17                Mayenne, DNUM: D53
# 18       Loire-Inférieure, DNUM: D44
# 19         Maine-et-Loire, DNUM: D49
# 20                 Sarthe, DNUM: D72
# 21         Indre-et-Loire, DNUM: D37
# 22           Loir-et-Cher, DNUM: D41
# 23                  Yonne, DNUM: D89
# 24                   Aube, DNUM: D10
# 25                  Marne, DNUM: D51
# 26            Deux-Sèvres, DNUM: D79
# 27                 Vienne, DNUM: D86
# 28                  Indre, DNUM: D36
# 29                   Cher, DNUM: D18
# 30                 Nièvre, DNUM: D58
# 31                 Allier, DNUM: D03
# 32                 Creuse, DNUM: D23
# 33           Haute-Vienne, DNUM: D87
# 34               Charente, DNUM: D16
# 35                Gironde, DNUM: D33
# 36               Dordogne, DNUM: D24
# 37                Corrèze, DNUM: D19
# 38            Puy-de-Dôme, DNUM: D63
# 39                 Cantal, DNUM: D15
# 40            Haute-Loire, DNUM: D43
# 41                 Landes, DNUM: D40
# 42      Hautes-Pyrénées-1, DNUM: D65
# 43      Hautes-Pyrénées-2, DNUM: D65
# 44        Basses-Pyrénées, DNUM: D64
# 45        Hautes-Pyrénées, DNUM: D65
# 46          Haute-Garonne, DNUM: D31
# 47                 Ariège, DNUM: D09
# 48                   Aude, DNUM: D11
# 49    Pyrénées-Orientales, DNUM: D66
# 50                Hérault, DNUM: D34
# 51                   Gard, DNUM: D30
# 52                   Gers, DNUM: D32
# 53         Lot-et-Garonne, DNUM: D47
# 54                    Lot, DNUM: D46
# 55                   Tarn, DNUM: D81
# 56                Aveyron, DNUM: D12
# 57                 Lozère, DNUM: D48
# 58                    Var, DNUM: D83
# 59           Basses-Alpes, DNUM: D04
# 60           Hautes-Alpes, DNUM: D05
# 61                  Isère, DNUM: D38
# 62                   Jura, DNUM: D39
# 63         Saône-et-Loire, DNUM: D71
# 64              Côte-d'Or, DNUM: D21
# 65            Haute-Marne, DNUM: D52
# 66                 Vosges, DNUM: D88
# 67                  Meuse, DNUM: D55
# 68                   Nord, DNUM: D59
# 69                 Vendée, DNUM: D85
# 70    Charente-Inférieure, DNUM: D17
# 71                  Rhône, DNUM: D69
# 72                  Loire, DNUM: D42
# 73                  Doubs, DNUM: D25
# 74       Bouches-du-Rhône, DNUM: D13
# 75                  Drôme, DNUM: D26
# 76               Vaucluse, DNUM: D84
# 77                 Savoie, DNUM: D73
# 78          anc-Haut-Rhin, DNUM: D90
# 79            Haute-Saône, DNUM: D70
# 80                Ardèche, DNUM: D07
# 81               Ardennes, DNUM: D08
# 82        Tarn et Garonne, DNUM: D82
# 83        Alpes-Maritimes, DNUM: D06
# 84                  Corse, DNUM: D20
# 85                    Ain, DNUM: D01
# 86           Haute-Savoie, DNUM: D74
# 87            anc-Meurthe, DNUM: D54
# dtype: object
